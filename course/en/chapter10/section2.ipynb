# %% [markdown]
# # Set up your Argilla instance

# %%
# !pip install -q argilla
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.3/161.3 kB 11.5 MB/s eta 0:00:00
# ...

# %%
import argilla as rg

ARGILLA_API_URL = "https://parthgeek-argilla-parth-test.hf.space/"
ARGILLA_API_KEY = "owner.apikey"

print("=" * 80)
print("Connecting to Argilla instance...")
print("URL:", ARGILLA_API_URL)
print("=" * 80)

client = rg.Argilla(
    api_url=ARGILLA_API_URL,
    api_key=ARGILLA_API_KEY,
)

print("Connected successfully.")
print(client)
print("=" * 80)
# Out:
# /usr/local/lib/python3.12/dist-packages/argilla/_api/_token.py:83: UserWarning:
# The secrets ARGILLA_API_URL and does not exist in your Colab secrets.
#   warnings.warn(f"\nThe secrets {name} and does not exist in your Colab secrets.")
# /usr/local/lib/python3.12/dist-packages/argilla/_api/_token.py:83: UserWarning:
# The secrets ARGILLA_API_KEY and does not exist in your Colab secrets.
#   warnings.warn(f"\nThe secrets {name} and does not exist in your Colab secrets.")
# ...
# Connecting to Argilla instance...
# URL: https://parthgeek-argilla-parth-test.hf.space/
# ...
# Connected successfully.
#         <iframe
#             width="850"
#             height="600"
#             src="https://parthgeek-argilla-parth-test.hf.space/?frameborder=0"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# Argilla has been deployed at: https://parthgeek-argilla-parth-test.hf.space/
# ...

# %%
print("=" * 80)
print("Checking current Argilla user...")
print("=" * 80)

me = client.me

print(me)
print("=" * 80)
# Out:
# ...
# Checking current Argilla user...
# ...
# User(id=UUID('5797d6c0-9fe8-4332-a06f-26e1d61cb2ec') inserted_at=datetime.datetime(2026, 5, 18, 4, 4, 52, 33875) updated_at=datetime.datetime(2026, 5, 18, 4, 4, 52, 33875) username='ParthGeek' role=<Role.owner: 'owner'> first_name='ParthGeek' last_name=None password=None)
# ...
